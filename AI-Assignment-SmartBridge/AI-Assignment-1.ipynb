# %% [markdown]
# # **AI ASSIGNMENT-1**
#
# > Indented block

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### **TASK-1**

# %%
f1=pd.Series(np.random.rand(4))
f2=pd.Series(np.random.rand(4))
f3=pd.Series(np.random.rand(4))
f4=pd.Series(np.random.rand(4))

# %%
print(f1,f2,f3,f4)
# Out:
# 0    0.679127
# 1    0.079154
# 2    0.615255
# 3    0.244782
# dtype: float64 0    0.413205
# 1    0.892379
# 2    0.986615
# 3    0.552592
# dtype: float64 0    0.106180
# 1    0.247602
# 2    0.062358
# 3    0.087665
# dtype: float64 0    0.112810
# 1    0.855243
# 2    0.430734
# 3    0.741630
# dtype: float64

# %%
data=pd.DataFrame([f1,f2,f3,f4])
data
# Out:
#           0         1         2         3
# 0  0.679127  0.079154  0.615255  0.244782
# 1  0.413205  0.892379  0.986615  0.552592
# 2  0.106180  0.247602  0.062358  0.087665
# 3  0.112810  0.855243  0.430734  0.741630

# %% [markdown]
# ### **TASK-2**

# %%
data.columns=["Random Value 1","Random Value 2","Random Value 3","Random Value 4"]
data
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0        0.679127        0.079154        0.615255        0.244782
# 1        0.413205        0.892379        0.986615        0.552592
# 2        0.106180        0.247602        0.062358        0.087665
# 3        0.112810        0.855243        0.430734        0.741630

# %% [markdown]
# ### **Task-3**

# %%
data.describe(include='all')
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.327831        0.518594        0.523740        0.406667
# std          0.274506        0.416170        0.384774        0.295219
# min          0.106180        0.079154        0.062358        0.087665
# 25%          0.111153        0.205490        0.338640        0.205503
# 50%          0.263008        0.551423        0.522994        0.398687
# 75%          0.479686        0.864527        0.708095        0.599851
# max          0.679127        0.892379        0.986615        0.741630

# %% [markdown]
# ### **TASK-4**

# %%
data.isnull().sum()
# Out:
# Random Value 1    0
# Random Value 2    0
# Random Value 3    0
# Random Value 4    0
# dtype: int64

# %% [markdown]
# ### **TASK-5**

# %%
data.loc[0:,'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0        0.079154        0.615255
# 1        0.892379        0.986615
# 2        0.247602        0.062358
# 3        0.855243        0.430734

# %%
data.iloc[0:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0        0.079154        0.615255
# 1        0.892379        0.986615
# 2        0.247602        0.062358
# 3        0.855243        0.430734
